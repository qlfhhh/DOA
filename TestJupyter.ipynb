# %%
import pandas as pd
from matplotlib import pyplot as plt
data = pd.read_excel("./1.xls")
print(data)
# Out:
#                        通道  X轴坐标（mm）  Y轴坐标（mm）
# 0                     CH1   -17.192     0.000
# 1                     CH2   -16.031     6.210
# 2                     CH3   -12.705   -11.582
# 3                     CH4    -7.663    15.390
# 4                     CH5    -1.586   -17.119
# ..                    ...       ...       ...
# 125                 CH126    -7.660    -6.428
# 126                 CH127   -10.000     0.000
# 127                 CH128    -7.660     6.428
# 128                   NaN       NaN       NaN
# 129  注：此坐标为麦克风阵列对外视角，如右图。       NaN       NaN
#
# [130 rows x 3 columns]

# %%
x,y = data["X轴坐标（mm）"],data["Y轴坐标（mm）"]
plt.figure()
for i in range(128):
    plt.scatter(x[i],y[i],color="r")
plt.show()
